# %% [markdown]
# ## 1. Static Deployment

# %% [markdown]
# ## 2. Dynamic Deployment on User’s Device
#
# As with static deployment, deploying to a user’s device makes it difficult to monitor the model performance.

# %% [markdown]
# ## 3. Dynamic Deployment on a Server
#
#
#
# - Deployment on a Virtual Machine
#
#     In Python, a REST API web service is usually implemented using a web application framework
# such as Flask or FastAPI.
#
#     **REST API**: Representational State Transfer application programming interface
#
# - Deployment in a Container

# %% [markdown]
# ## 4. Model Streaming

# %% [markdown]
# ![image.png](attachment:image.png)
